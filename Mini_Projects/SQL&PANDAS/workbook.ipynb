# %%
df = pd.read_csv(r'C:\Users\theri\Downloads\datasetPandas\single_amazon_laptop_messy_dataset_1-10.csv')
# Out:
# Running cells with 'Python 3.13.13' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/william.richardson/Downloads/completed-projects/.venv/Scripts/python.exe -m pip install ipykernel -U --user --force-reinstall'
